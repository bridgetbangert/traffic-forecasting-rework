# %%
import requests
import re
from bs4 import BeautifulSoup
from io import BytesIO
import zipfile

# %%
# %run ../Framework/ADLSClient.ipynb

# %%
def download_and_upload(url, adls_container_client, adls_directory, latest_downloaded_file):
    try:
        print(f"Retrieving zip file from {url}.")
        response = requests.get(url, stream=True, timeout=60)
        response.raise_for_status()
        zip_file = BytesIO(response.content)
        print(f"{url} has been successfully stored in memory.")

        with zipfile.ZipFile(zip_file) as zf:
            for file_name in zf.namelist():
                if file_name.endswith('/'):
                    continue

                with zf.open(file_name) as file_data:
                    upload_path = f"{adls_directory}/{url.split('/')[-2]}/{file_name}"
                    print(f"Uploading {file_name} to ADLS at {upload_path}.")
                    
                    blob_client = adls_container_client.get_blob_client(upload_path)
                    blob_client.upload_blob(file_data.read(), overwrite=True)
                    print(f"Uploaded {file_name} successfully.")
    
    except requests.exceptions.RequestException as e:
        print(f"Failed to download ZIP file: {e}")
        
    except zipfile.BadZipFile:
        print("The downloaded file is not a valid ZIP file.")
        
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
# create ADLS container client
adls_client = ADLSClient()
adls_container_client = adls_client.create_container_client()
adls_dir = "fhwa_import"

# get all downloadable content on the FHWA website
url = "https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/"
html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")

# all links to downloadable zip file
links = [a["href"] for a in soup.find_all("a", href=True)]
links = [f"{url}{link}" for link in links if ".zip" in link]

# get latest downloaded file in ADLS to treat as an offset
latest_ingested_file = max(
    ['/'.join(blob.name.split('/')[-2:]) for blob in adls_container_client.list_blobs() 
    if "fhwa_import/" in blob.name 
    and "Delimited_CleanData" not in blob.name]
)

# filter for any files greater than the lastest offset
urls = [link for link in links 
        if re.findall(r"/(\d{4})/", link)[0] >= re.findall(r"(\d{4})", latest_ingested_file)[0]]

# %%
for url in urls:
    download_and_upload(url, adls_container_client, adls_dir, latest_ingested_file)
# Out:
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/2019_station_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/2019_station_data.zip has been successfully stored in memory.
# Uploading Station_Data_Extract_Pipe_Delimited_CleanData_2019.txt to ADLS at fhwa_import/2019/Station_Data_Extract_Pipe_Delimited_CleanData_2019.txt.
# Uploaded Station_Data_Extract_Pipe_Delimited_CleanData_2019.txt successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/jan_2019_ccs_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/jan_2019_ccs_data.zip has been successfully stored in memory.
# Uploading january_2019/AK0119.VOL to ADLS at fhwa_import/2019/january_2019/AK0119.VOL.
# Uploaded january_2019/AK0119.VOL successfully.
# Uploading january_2019/AL0119.VOL to ADLS at fhwa_import/2019/january_2019/AL0119.VOL.
# Uploaded january_2019/AL0119.VOL successfully.
# Uploading january_2019/AR0119.VOL to ADLS at fhwa_import/2019/january_2019/AR0119.VOL.
# Uploaded january_2019/AR0119.VOL successfully.
# Uploading january_2019/AZ0119.VOL to ADLS at fhwa_import/2019/january_2019/AZ0119.VOL.
# Uploaded january_2019/AZ0119.VOL successfully.
# Uploading january_2019/CA0119.VOL to ADLS at fhwa_import/2019/january_2019/CA0119.VOL.
# Uploaded january_2019/CA0119.VOL successfully.
# Uploading january_2019/CO0119.VOL to ADLS at fhwa_import/2019/january_2019/CO0119.VOL.
# Uploaded january_2019/CO0119.VOL successfully.
# Uploading january_2019/CT0119.VOL to ADLS at fhwa_import/2019/january_2019/CT0119.VOL.
# Uploaded january_2019/CT0119.VOL successfully.
# Uploading january_2019/DC0119.VOL to ADLS at fhwa_import/2019/january_2019/DC0119.VOL.
# Uploaded january_2019/DC0119.VOL successfully.
# Uploading january_2019/DE0119.VOL to ADLS at fhwa_import/2019/january_2019/DE0119.VOL.
# Uploaded january_2019/DE0119.VOL successfully.
# Uploading january_2019/FL0119.VOL to ADLS at fhwa_import/2019/january_2019/FL0119.VOL.
# Uploaded january_2019/FL0119.VOL successfully.
# Uploading january_2019/GA0119.VOL to ADLS at fhwa_import/2019/january_2019/GA0119.VOL.
# Uploaded january_2019/GA0119.VOL successfully.
# Uploading january_2019/HI0119.VOL to ADLS at fhwa_import/2019/january_2019/HI0119.VOL.
# Uploaded january_2019/HI0119.VOL successfully.
# Uploading january_2019/IA0119.VOL to ADLS at fhwa_import/2019/january_2019/IA0119.VOL.
# Uploaded january_2019/IA0119.VOL successfully.
# Uploading january_2019/ID0119.VOL to ADLS at fhwa_import/2019/january_2019/ID0119.VOL.
# Uploaded january_2019/ID0119.VOL successfully.
# Uploading january_2019/IL0119.VOL to ADLS at fhwa_import/2019/january_2019/IL0119.VOL.
# Uploaded january_2019/IL0119.VOL successfully.
# Uploading january_2019/IN0119.VOL to ADLS at fhwa_import/2019/january_2019/IN0119.VOL.
# Uploaded january_2019/IN0119.VOL successfully.
# Uploading january_2019/KS0119.VOL to ADLS at fhwa_import/2019/january_2019/KS0119.VOL.
# Uploaded january_2019/KS0119.VOL successfully.
# Uploading january_2019/KY0119.VOL to ADLS at fhwa_import/2019/january_2019/KY0119.VOL.
# Uploaded january_2019/KY0119.VOL successfully.
# Uploading january_2019/LA0119.VOL to ADLS at fhwa_import/2019/january_2019/LA0119.VOL.
# Uploaded january_2019/LA0119.VOL successfully.
# Uploading january_2019/MA0119.VOL to ADLS at fhwa_import/2019/january_2019/MA0119.VOL.
# Uploaded january_2019/MA0119.VOL successfully.
# Uploading january_2019/MD0119.VOL to ADLS at fhwa_import/2019/january_2019/MD0119.VOL.
# Uploaded january_2019/MD0119.VOL successfully.
# Uploading january_2019/ME0119.VOL to ADLS at fhwa_import/2019/january_2019/ME0119.VOL.
# Uploaded january_2019/ME0119.VOL successfully.
# Uploading january_2019/MI0119.VOL to ADLS at fhwa_import/2019/january_2019/MI0119.VOL.
# Uploaded january_2019/MI0119.VOL successfully.
# Uploading january_2019/MN0119.VOL to ADLS at fhwa_import/2019/january_2019/MN0119.VOL.
# Uploaded january_2019/MN0119.VOL successfully.
# Uploading january_2019/MO0119.VOL to ADLS at fhwa_import/2019/january_2019/MO0119.VOL.
# Uploaded january_2019/MO0119.VOL successfully.
# Uploading january_2019/MS0119.VOL to ADLS at fhwa_import/2019/january_2019/MS0119.VOL.
# Uploaded january_2019/MS0119.VOL successfully.
# Uploading january_2019/MT0119.VOL to ADLS at fhwa_import/2019/january_2019/MT0119.VOL.
# Uploaded january_2019/MT0119.VOL successfully.
# Uploading january_2019/NC0119.VOL to ADLS at fhwa_import/2019/january_2019/NC0119.VOL.
# Uploaded january_2019/NC0119.VOL successfully.
# Uploading january_2019/ND0119.VOL to ADLS at fhwa_import/2019/january_2019/ND0119.VOL.
# Uploaded january_2019/ND0119.VOL successfully.
# Uploading january_2019/NE0119.VOL to ADLS at fhwa_import/2019/january_2019/NE0119.VOL.
# Uploaded january_2019/NE0119.VOL successfully.
# Uploading january_2019/NH0119.VOL to ADLS at fhwa_import/2019/january_2019/NH0119.VOL.
# Uploaded january_2019/NH0119.VOL successfully.
# Uploading january_2019/NJ0119.VOL to ADLS at fhwa_import/2019/january_2019/NJ0119.VOL.
# Uploaded january_2019/NJ0119.VOL successfully.
# Uploading january_2019/NM0119.VOL to ADLS at fhwa_import/2019/january_2019/NM0119.VOL.
# Uploaded january_2019/NM0119.VOL successfully.
# Uploading january_2019/NV0119.VOL to ADLS at fhwa_import/2019/january_2019/NV0119.VOL.
# Uploaded january_2019/NV0119.VOL successfully.
# Uploading january_2019/NY0119.VOL to ADLS at fhwa_import/2019/january_2019/NY0119.VOL.
# Uploaded january_2019/NY0119.VOL successfully.
# Uploading january_2019/OH0119.VOL to ADLS at fhwa_import/2019/january_2019/OH0119.VOL.
# Uploaded january_2019/OH0119.VOL successfully.
# Uploading january_2019/OK0119.VOL to ADLS at fhwa_import/2019/january_2019/OK0119.VOL.
# Uploaded january_2019/OK0119.VOL successfully.
# Uploading january_2019/OR0119.VOL to ADLS at fhwa_import/2019/january_2019/OR0119.VOL.
# Uploaded january_2019/OR0119.VOL successfully.
# Uploading january_2019/PA0119.VOL to ADLS at fhwa_import/2019/january_2019/PA0119.VOL.
# Uploaded january_2019/PA0119.VOL successfully.
# Uploading january_2019/RI0119.VOL to ADLS at fhwa_import/2019/january_2019/RI0119.VOL.
# Uploaded january_2019/RI0119.VOL successfully.
# Uploading january_2019/SC0119.VOL to ADLS at fhwa_import/2019/january_2019/SC0119.VOL.
# Uploaded january_2019/SC0119.VOL successfully.
# Uploading january_2019/SD0119.VOL to ADLS at fhwa_import/2019/january_2019/SD0119.VOL.
# Uploaded january_2019/SD0119.VOL successfully.
# Uploading january_2019/TN0119.VOL to ADLS at fhwa_import/2019/january_2019/TN0119.VOL.
# Uploaded january_2019/TN0119.VOL successfully.
# Uploading january_2019/TX0119.VOL to ADLS at fhwa_import/2019/january_2019/TX0119.VOL.
# Uploaded january_2019/TX0119.VOL successfully.
# Uploading january_2019/UT0119.VOL to ADLS at fhwa_import/2019/january_2019/UT0119.VOL.
# Uploaded january_2019/UT0119.VOL successfully.
# Uploading january_2019/VA0119.VOL to ADLS at fhwa_import/2019/january_2019/VA0119.VOL.
# Uploaded january_2019/VA0119.VOL successfully.
# Uploading january_2019/VT0119.VOL to ADLS at fhwa_import/2019/january_2019/VT0119.VOL.
# Uploaded january_2019/VT0119.VOL successfully.
# Uploading january_2019/WA0119.VOL to ADLS at fhwa_import/2019/january_2019/WA0119.VOL.
# Uploaded january_2019/WA0119.VOL successfully.
# Uploading january_2019/WI0119.VOL to ADLS at fhwa_import/2019/january_2019/WI0119.VOL.
# Uploaded january_2019/WI0119.VOL successfully.
# Uploading january_2019/WV0119.VOL to ADLS at fhwa_import/2019/january_2019/WV0119.VOL.
# Uploaded january_2019/WV0119.VOL successfully.
# Uploading january_2019/WY0119.VOL to ADLS at fhwa_import/2019/january_2019/WY0119.VOL.
# Uploaded january_2019/WY0119.VOL successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/feb_2019_ccs_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/feb_2019_ccs_data.zip has been successfully stored in memory.
# Uploading february_2019/AK0219.VOL to ADLS at fhwa_import/2019/february_2019/AK0219.VOL.
# Uploaded february_2019/AK0219.VOL successfully.
# Uploading february_2019/AL0219.VOL to ADLS at fhwa_import/2019/february_2019/AL0219.VOL.
# Uploaded february_2019/AL0219.VOL successfully.
# Uploading february_2019/AR0219.VOL to ADLS at fhwa_import/2019/february_2019/AR0219.VOL.
# Uploaded february_2019/AR0219.VOL successfully.
# Uploading february_2019/AZ0219.VOL to ADLS at fhwa_import/2019/february_2019/AZ0219.VOL.
# Uploaded february_2019/AZ0219.VOL successfully.
# Uploading february_2019/CA0219.VOL to ADLS at fhwa_import/2019/february_2019/CA0219.VOL.
# Uploaded february_2019/CA0219.VOL successfully.
# Uploading february_2019/CO0219.VOL to ADLS at fhwa_import/2019/february_2019/CO0219.VOL.
# Uploaded february_2019/CO0219.VOL successfully.
# Uploading february_2019/CT0219.VOL to ADLS at fhwa_import/2019/february_2019/CT0219.VOL.
# Uploaded february_2019/CT0219.VOL successfully.
# Uploading february_2019/DC0219.VOL to ADLS at fhwa_import/2019/february_2019/DC0219.VOL.
# Uploaded february_2019/DC0219.VOL successfully.
# Uploading february_2019/DE0219.VOL to ADLS at fhwa_import/2019/february_2019/DE0219.VOL.
# Uploaded february_2019/DE0219.VOL successfully.
# Uploading february_2019/FL0219.VOL to ADLS at fhwa_import/2019/february_2019/FL0219.VOL.
# Uploaded february_2019/FL0219.VOL successfully.
# Uploading february_2019/GA0219.VOL to ADLS at fhwa_import/2019/february_2019/GA0219.VOL.
# Uploaded february_2019/GA0219.VOL successfully.
# Uploading february_2019/HI0219.VOL to ADLS at fhwa_import/2019/february_2019/HI0219.VOL.
# Uploaded february_2019/HI0219.VOL successfully.
# Uploading february_2019/IA0219.VOL to ADLS at fhwa_import/2019/february_2019/IA0219.VOL.
# Uploaded february_2019/IA0219.VOL successfully.
# Uploading february_2019/ID0219.VOL to ADLS at fhwa_import/2019/february_2019/ID0219.VOL.
# Uploaded february_2019/ID0219.VOL successfully.
# Uploading february_2019/IL0219.VOL to ADLS at fhwa_import/2019/february_2019/IL0219.VOL.
# Uploaded february_2019/IL0219.VOL successfully.
# Uploading february_2019/IN0219.VOL to ADLS at fhwa_import/2019/february_2019/IN0219.VOL.
# Uploaded february_2019/IN0219.VOL successfully.
# Uploading february_2019/KS0219.VOL to ADLS at fhwa_import/2019/february_2019/KS0219.VOL.
# Uploaded february_2019/KS0219.VOL successfully.
# Uploading february_2019/KY0219.VOL to ADLS at fhwa_import/2019/february_2019/KY0219.VOL.
# Uploaded february_2019/KY0219.VOL successfully.
# Uploading february_2019/LA0219.VOL to ADLS at fhwa_import/2019/february_2019/LA0219.VOL.
# Uploaded february_2019/LA0219.VOL successfully.
# Uploading february_2019/MA0219.VOL to ADLS at fhwa_import/2019/february_2019/MA0219.VOL.
# Uploaded february_2019/MA0219.VOL successfully.
# Uploading february_2019/MD0219.VOL to ADLS at fhwa_import/2019/february_2019/MD0219.VOL.
# Uploaded february_2019/MD0219.VOL successfully.
# Uploading february_2019/ME0219.VOL to ADLS at fhwa_import/2019/february_2019/ME0219.VOL.
# Uploaded february_2019/ME0219.VOL successfully.
# Uploading february_2019/MI0219.VOL to ADLS at fhwa_import/2019/february_2019/MI0219.VOL.
# Uploaded february_2019/MI0219.VOL successfully.
# Uploading february_2019/MN0219.VOL to ADLS at fhwa_import/2019/february_2019/MN0219.VOL.
# Uploaded february_2019/MN0219.VOL successfully.
# Uploading february_2019/MO0219.VOL to ADLS at fhwa_import/2019/february_2019/MO0219.VOL.
# Uploaded february_2019/MO0219.VOL successfully.
# Uploading february_2019/MS0219.VOL to ADLS at fhwa_import/2019/february_2019/MS0219.VOL.
# Uploaded february_2019/MS0219.VOL successfully.
# Uploading february_2019/MT0219.VOL to ADLS at fhwa_import/2019/february_2019/MT0219.VOL.
# Uploaded february_2019/MT0219.VOL successfully.
# Uploading february_2019/NC0219.VOL to ADLS at fhwa_import/2019/february_2019/NC0219.VOL.
# Uploaded february_2019/NC0219.VOL successfully.
# Uploading february_2019/ND0219.VOL to ADLS at fhwa_import/2019/february_2019/ND0219.VOL.
# Uploaded february_2019/ND0219.VOL successfully.
# Uploading february_2019/NE0219.VOL to ADLS at fhwa_import/2019/february_2019/NE0219.VOL.
# Uploaded february_2019/NE0219.VOL successfully.
# Uploading february_2019/NH0219.VOL to ADLS at fhwa_import/2019/february_2019/NH0219.VOL.
# Uploaded february_2019/NH0219.VOL successfully.
# Uploading february_2019/NJ0219.VOL to ADLS at fhwa_import/2019/february_2019/NJ0219.VOL.
# Uploaded february_2019/NJ0219.VOL successfully.
# Uploading february_2019/NM0219.VOL to ADLS at fhwa_import/2019/february_2019/NM0219.VOL.
# Uploaded february_2019/NM0219.VOL successfully.
# Uploading february_2019/NV0219.VOL to ADLS at fhwa_import/2019/february_2019/NV0219.VOL.
# Uploaded february_2019/NV0219.VOL successfully.
# Uploading february_2019/NY0219.VOL to ADLS at fhwa_import/2019/february_2019/NY0219.VOL.
# Uploaded february_2019/NY0219.VOL successfully.
# Uploading february_2019/OH0219.VOL to ADLS at fhwa_import/2019/february_2019/OH0219.VOL.
# Uploaded february_2019/OH0219.VOL successfully.
# Uploading february_2019/OK0219.VOL to ADLS at fhwa_import/2019/february_2019/OK0219.VOL.
# Uploaded february_2019/OK0219.VOL successfully.
# Uploading february_2019/OR0219.VOL to ADLS at fhwa_import/2019/february_2019/OR0219.VOL.
# Uploaded february_2019/OR0219.VOL successfully.
# Uploading february_2019/PA0219.VOL to ADLS at fhwa_import/2019/february_2019/PA0219.VOL.
# Uploaded february_2019/PA0219.VOL successfully.
# Uploading february_2019/RI0219.VOL to ADLS at fhwa_import/2019/february_2019/RI0219.VOL.
# Uploaded february_2019/RI0219.VOL successfully.
# Uploading february_2019/SC0219.VOL to ADLS at fhwa_import/2019/february_2019/SC0219.VOL.
# Uploaded february_2019/SC0219.VOL successfully.
# Uploading february_2019/SD0219.VOL to ADLS at fhwa_import/2019/february_2019/SD0219.VOL.
# Uploaded february_2019/SD0219.VOL successfully.
# Uploading february_2019/TN0219.VOL to ADLS at fhwa_import/2019/february_2019/TN0219.VOL.
# Uploaded february_2019/TN0219.VOL successfully.
# Uploading february_2019/TX0219.VOL to ADLS at fhwa_import/2019/february_2019/TX0219.VOL.
# Uploaded february_2019/TX0219.VOL successfully.
# Uploading february_2019/UT0219.VOL to ADLS at fhwa_import/2019/february_2019/UT0219.VOL.
# Uploaded february_2019/UT0219.VOL successfully.
# Uploading february_2019/VA0219.VOL to ADLS at fhwa_import/2019/february_2019/VA0219.VOL.
# Uploaded february_2019/VA0219.VOL successfully.
# Uploading february_2019/VT0219.VOL to ADLS at fhwa_import/2019/february_2019/VT0219.VOL.
# Uploaded february_2019/VT0219.VOL successfully.
# Uploading february_2019/WA0219.VOL to ADLS at fhwa_import/2019/february_2019/WA0219.VOL.
# Uploaded february_2019/WA0219.VOL successfully.
# Uploading february_2019/WI0219.VOL to ADLS at fhwa_import/2019/february_2019/WI0219.VOL.
# Uploaded february_2019/WI0219.VOL successfully.
# Uploading february_2019/WV0219.VOL to ADLS at fhwa_import/2019/february_2019/WV0219.VOL.
# Uploaded february_2019/WV0219.VOL successfully.
# Uploading february_2019/WY0219.VOL to ADLS at fhwa_import/2019/february_2019/WY0219.VOL.
# Uploaded february_2019/WY0219.VOL successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/mar_2019_ccs_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/mar_2019_ccs_data.zip has been successfully stored in memory.
# Uploading march_2019/AK0319.VOL to ADLS at fhwa_import/2019/march_2019/AK0319.VOL.
# Uploaded march_2019/AK0319.VOL successfully.
# Uploading march_2019/AL0319.VOL to ADLS at fhwa_import/2019/march_2019/AL0319.VOL.
# Uploaded march_2019/AL0319.VOL successfully.
# Uploading march_2019/AR0319.VOL to ADLS at fhwa_import/2019/march_2019/AR0319.VOL.
# Uploaded march_2019/AR0319.VOL successfully.
# Uploading march_2019/AZ0319.VOL to ADLS at fhwa_import/2019/march_2019/AZ0319.VOL.
# Uploaded march_2019/AZ0319.VOL successfully.
# Uploading march_2019/CA0319.VOL to ADLS at fhwa_import/2019/march_2019/CA0319.VOL.
# Uploaded march_2019/CA0319.VOL successfully.
# Uploading march_2019/CO0319.VOL to ADLS at fhwa_import/2019/march_2019/CO0319.VOL.
# Uploaded march_2019/CO0319.VOL successfully.
# Uploading march_2019/CT0319.VOL to ADLS at fhwa_import/2019/march_2019/CT0319.VOL.
# Uploaded march_2019/CT0319.VOL successfully.
# Uploading march_2019/DC0319.VOL to ADLS at fhwa_import/2019/march_2019/DC0319.VOL.
# Uploaded march_2019/DC0319.VOL successfully.
# Uploading march_2019/DE0319.VOL to ADLS at fhwa_import/2019/march_2019/DE0319.VOL.
# Uploaded march_2019/DE0319.VOL successfully.
# Uploading march_2019/FL0319.VOL to ADLS at fhwa_import/2019/march_2019/FL0319.VOL.
# Uploaded march_2019/FL0319.VOL successfully.
# Uploading march_2019/GA0319.VOL to ADLS at fhwa_import/2019/march_2019/GA0319.VOL.
# Uploaded march_2019/GA0319.VOL successfully.
# Uploading march_2019/HI0319.VOL to ADLS at fhwa_import/2019/march_2019/HI0319.VOL.
# Uploaded march_2019/HI0319.VOL successfully.
# Uploading march_2019/IA0319.VOL to ADLS at fhwa_import/2019/march_2019/IA0319.VOL.
# Uploaded march_2019/IA0319.VOL successfully.
# Uploading march_2019/ID0319.VOL to ADLS at fhwa_import/2019/march_2019/ID0319.VOL.
# Uploaded march_2019/ID0319.VOL successfully.
# Uploading march_2019/IL0319.VOL to ADLS at fhwa_import/2019/march_2019/IL0319.VOL.
# Uploaded march_2019/IL0319.VOL successfully.
# Uploading march_2019/IN0319.VOL to ADLS at fhwa_import/2019/march_2019/IN0319.VOL.
# Uploaded march_2019/IN0319.VOL successfully.
# Uploading march_2019/KS0319.VOL to ADLS at fhwa_import/2019/march_2019/KS0319.VOL.
# Uploaded march_2019/KS0319.VOL successfully.
# Uploading march_2019/KY0319.VOL to ADLS at fhwa_import/2019/march_2019/KY0319.VOL.
# Uploaded march_2019/KY0319.VOL successfully.
# Uploading march_2019/LA0319.VOL to ADLS at fhwa_import/2019/march_2019/LA0319.VOL.
# Uploaded march_2019/LA0319.VOL successfully.
# Uploading march_2019/MA0319.VOL to ADLS at fhwa_import/2019/march_2019/MA0319.VOL.
# Uploaded march_2019/MA0319.VOL successfully.
# Uploading march_2019/MD0319.VOL to ADLS at fhwa_import/2019/march_2019/MD0319.VOL.
# Uploaded march_2019/MD0319.VOL successfully.
# Uploading march_2019/ME0319.VOL to ADLS at fhwa_import/2019/march_2019/ME0319.VOL.
# Uploaded march_2019/ME0319.VOL successfully.
# Uploading march_2019/MI0319.VOL to ADLS at fhwa_import/2019/march_2019/MI0319.VOL.
# Uploaded march_2019/MI0319.VOL successfully.
# Uploading march_2019/MN0319.VOL to ADLS at fhwa_import/2019/march_2019/MN0319.VOL.
# Uploaded march_2019/MN0319.VOL successfully.
# Uploading march_2019/MO0319.VOL to ADLS at fhwa_import/2019/march_2019/MO0319.VOL.
# Uploaded march_2019/MO0319.VOL successfully.
# Uploading march_2019/MS0319.VOL to ADLS at fhwa_import/2019/march_2019/MS0319.VOL.
# Uploaded march_2019/MS0319.VOL successfully.
# Uploading march_2019/MT0319.VOL to ADLS at fhwa_import/2019/march_2019/MT0319.VOL.
# Uploaded march_2019/MT0319.VOL successfully.
# Uploading march_2019/NC0319.VOL to ADLS at fhwa_import/2019/march_2019/NC0319.VOL.
# Uploaded march_2019/NC0319.VOL successfully.
# Uploading march_2019/ND0319.VOL to ADLS at fhwa_import/2019/march_2019/ND0319.VOL.
# Uploaded march_2019/ND0319.VOL successfully.
# Uploading march_2019/NE0319.VOL to ADLS at fhwa_import/2019/march_2019/NE0319.VOL.
# Uploaded march_2019/NE0319.VOL successfully.
# Uploading march_2019/NH0319.VOL to ADLS at fhwa_import/2019/march_2019/NH0319.VOL.
# Uploaded march_2019/NH0319.VOL successfully.
# Uploading march_2019/NJ0319.VOL to ADLS at fhwa_import/2019/march_2019/NJ0319.VOL.
# Uploaded march_2019/NJ0319.VOL successfully.
# Uploading march_2019/NM0319.VOL to ADLS at fhwa_import/2019/march_2019/NM0319.VOL.
# Uploaded march_2019/NM0319.VOL successfully.
# Uploading march_2019/NV0319.VOL to ADLS at fhwa_import/2019/march_2019/NV0319.VOL.
# Uploaded march_2019/NV0319.VOL successfully.
# Uploading march_2019/NY0319.VOL to ADLS at fhwa_import/2019/march_2019/NY0319.VOL.
# Uploaded march_2019/NY0319.VOL successfully.
# Uploading march_2019/OH0319.VOL to ADLS at fhwa_import/2019/march_2019/OH0319.VOL.
# Uploaded march_2019/OH0319.VOL successfully.
# Uploading march_2019/OK0319.VOL to ADLS at fhwa_import/2019/march_2019/OK0319.VOL.
# Uploaded march_2019/OK0319.VOL successfully.
# Uploading march_2019/OR0319.VOL to ADLS at fhwa_import/2019/march_2019/OR0319.VOL.
# Uploaded march_2019/OR0319.VOL successfully.
# Uploading march_2019/PA0319.VOL to ADLS at fhwa_import/2019/march_2019/PA0319.VOL.
# Uploaded march_2019/PA0319.VOL successfully.
# Uploading march_2019/RI0319.VOL to ADLS at fhwa_import/2019/march_2019/RI0319.VOL.
# Uploaded march_2019/RI0319.VOL successfully.
# Uploading march_2019/SC0319.VOL to ADLS at fhwa_import/2019/march_2019/SC0319.VOL.
# Uploaded march_2019/SC0319.VOL successfully.
# Uploading march_2019/SD0319.VOL to ADLS at fhwa_import/2019/march_2019/SD0319.VOL.
# Uploaded march_2019/SD0319.VOL successfully.
# Uploading march_2019/TN0319.VOL to ADLS at fhwa_import/2019/march_2019/TN0319.VOL.
# Uploaded march_2019/TN0319.VOL successfully.
# Uploading march_2019/TX0319.VOL to ADLS at fhwa_import/2019/march_2019/TX0319.VOL.
# Uploaded march_2019/TX0319.VOL successfully.
# Uploading march_2019/UT0319.VOL to ADLS at fhwa_import/2019/march_2019/UT0319.VOL.
# Uploaded march_2019/UT0319.VOL successfully.
# Uploading march_2019/VA0319.VOL to ADLS at fhwa_import/2019/march_2019/VA0319.VOL.
# Uploaded march_2019/VA0319.VOL successfully.
# Uploading march_2019/VT0319.VOL to ADLS at fhwa_import/2019/march_2019/VT0319.VOL.
# Uploaded march_2019/VT0319.VOL successfully.
# Uploading march_2019/WA0319.VOL to ADLS at fhwa_import/2019/march_2019/WA0319.VOL.
# Uploaded march_2019/WA0319.VOL successfully.
# Uploading march_2019/WI0319.VOL to ADLS at fhwa_import/2019/march_2019/WI0319.VOL.
# Uploaded march_2019/WI0319.VOL successfully.
# Uploading march_2019/WV0319.VOL to ADLS at fhwa_import/2019/march_2019/WV0319.VOL.
# Uploaded march_2019/WV0319.VOL successfully.
# Uploading march_2019/WY0319.VOL to ADLS at fhwa_import/2019/march_2019/WY0319.VOL.
# Uploaded march_2019/WY0319.VOL successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/apr_2019_ccs_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/apr_2019_ccs_data.zip has been successfully stored in memory.
# Uploading april_2019/AK0419.VOL to ADLS at fhwa_import/2019/april_2019/AK0419.VOL.
# Uploaded april_2019/AK0419.VOL successfully.
# Uploading april_2019/AL0419.VOL to ADLS at fhwa_import/2019/april_2019/AL0419.VOL.
# Uploaded april_2019/AL0419.VOL successfully.
# Uploading april_2019/AR0419.VOL to ADLS at fhwa_import/2019/april_2019/AR0419.VOL.
# Uploaded april_2019/AR0419.VOL successfully.
# Uploading april_2019/AZ0419.VOL to ADLS at fhwa_import/2019/april_2019/AZ0419.VOL.
# Uploaded april_2019/AZ0419.VOL successfully.
# Uploading april_2019/CA0419.VOL to ADLS at fhwa_import/2019/april_2019/CA0419.VOL.
# Uploaded april_2019/CA0419.VOL successfully.
# Uploading april_2019/CO0419.VOL to ADLS at fhwa_import/2019/april_2019/CO0419.VOL.
# Uploaded april_2019/CO0419.VOL successfully.
# Uploading april_2019/CT0419.VOL to ADLS at fhwa_import/2019/april_2019/CT0419.VOL.
# Uploaded april_2019/CT0419.VOL successfully.
# Uploading april_2019/DC0419.VOL to ADLS at fhwa_import/2019/april_2019/DC0419.VOL.
# Uploaded april_2019/DC0419.VOL successfully.
# Uploading april_2019/DE0419.VOL to ADLS at fhwa_import/2019/april_2019/DE0419.VOL.
# Uploaded april_2019/DE0419.VOL successfully.
# Uploading april_2019/FL0419.VOL to ADLS at fhwa_import/2019/april_2019/FL0419.VOL.
# Uploaded april_2019/FL0419.VOL successfully.
# Uploading april_2019/GA0419.VOL to ADLS at fhwa_import/2019/april_2019/GA0419.VOL.
# Uploaded april_2019/GA0419.VOL successfully.
# Uploading april_2019/HI0419.VOL to ADLS at fhwa_import/2019/april_2019/HI0419.VOL.
# Uploaded april_2019/HI0419.VOL successfully.
# Uploading april_2019/IA0419.VOL to ADLS at fhwa_import/2019/april_2019/IA0419.VOL.
# Uploaded april_2019/IA0419.VOL successfully.
# Uploading april_2019/ID0419.VOL to ADLS at fhwa_import/2019/april_2019/ID0419.VOL.
# Uploaded april_2019/ID0419.VOL successfully.
# Uploading april_2019/IL0419.VOL to ADLS at fhwa_import/2019/april_2019/IL0419.VOL.
# Uploaded april_2019/IL0419.VOL successfully.
# Uploading april_2019/IN0419.VOL to ADLS at fhwa_import/2019/april_2019/IN0419.VOL.
# Uploaded april_2019/IN0419.VOL successfully.
# Uploading april_2019/KS0419.VOL to ADLS at fhwa_import/2019/april_2019/KS0419.VOL.
# Uploaded april_2019/KS0419.VOL successfully.
# Uploading april_2019/KY0419.VOL to ADLS at fhwa_import/2019/april_2019/KY0419.VOL.
# Uploaded april_2019/KY0419.VOL successfully.
# Uploading april_2019/LA0419.VOL to ADLS at fhwa_import/2019/april_2019/LA0419.VOL.
# Uploaded april_2019/LA0419.VOL successfully.
# Uploading april_2019/MA0419.VOL to ADLS at fhwa_import/2019/april_2019/MA0419.VOL.
# Uploaded april_2019/MA0419.VOL successfully.
# Uploading april_2019/MD0419.VOL to ADLS at fhwa_import/2019/april_2019/MD0419.VOL.
# Uploaded april_2019/MD0419.VOL successfully.
# Uploading april_2019/ME0419.VOL to ADLS at fhwa_import/2019/april_2019/ME0419.VOL.
# Uploaded april_2019/ME0419.VOL successfully.
# Uploading april_2019/MI0419.VOL to ADLS at fhwa_import/2019/april_2019/MI0419.VOL.
# Uploaded april_2019/MI0419.VOL successfully.
# Uploading april_2019/MN0419.VOL to ADLS at fhwa_import/2019/april_2019/MN0419.VOL.
# Uploaded april_2019/MN0419.VOL successfully.
# Uploading april_2019/MO0419.VOL to ADLS at fhwa_import/2019/april_2019/MO0419.VOL.
# Uploaded april_2019/MO0419.VOL successfully.
# Uploading april_2019/MS0419.VOL to ADLS at fhwa_import/2019/april_2019/MS0419.VOL.
# Uploaded april_2019/MS0419.VOL successfully.
# Uploading april_2019/MT0419.VOL to ADLS at fhwa_import/2019/april_2019/MT0419.VOL.
# Uploaded april_2019/MT0419.VOL successfully.
# Uploading april_2019/NC0419.VOL to ADLS at fhwa_import/2019/april_2019/NC0419.VOL.
# Uploaded april_2019/NC0419.VOL successfully.
# Uploading april_2019/ND0419.VOL to ADLS at fhwa_import/2019/april_2019/ND0419.VOL.
# Uploaded april_2019/ND0419.VOL successfully.
# Uploading april_2019/NE0419.VOL to ADLS at fhwa_import/2019/april_2019/NE0419.VOL.
# Uploaded april_2019/NE0419.VOL successfully.
# Uploading april_2019/NH0419.VOL to ADLS at fhwa_import/2019/april_2019/NH0419.VOL.
# Uploaded april_2019/NH0419.VOL successfully.
# Uploading april_2019/NJ0419.VOL to ADLS at fhwa_import/2019/april_2019/NJ0419.VOL.
# Uploaded april_2019/NJ0419.VOL successfully.
# Uploading april_2019/NM0419.VOL to ADLS at fhwa_import/2019/april_2019/NM0419.VOL.
# Uploaded april_2019/NM0419.VOL successfully.
# Uploading april_2019/NV0419.VOL to ADLS at fhwa_import/2019/april_2019/NV0419.VOL.
# Uploaded april_2019/NV0419.VOL successfully.
# Uploading april_2019/NY0419.VOL to ADLS at fhwa_import/2019/april_2019/NY0419.VOL.
# Uploaded april_2019/NY0419.VOL successfully.
# Uploading april_2019/OH0419.VOL to ADLS at fhwa_import/2019/april_2019/OH0419.VOL.
# Uploaded april_2019/OH0419.VOL successfully.
# Uploading april_2019/OK0419.VOL to ADLS at fhwa_import/2019/april_2019/OK0419.VOL.
# Uploaded april_2019/OK0419.VOL successfully.
# Uploading april_2019/OR0419.VOL to ADLS at fhwa_import/2019/april_2019/OR0419.VOL.
# Uploaded april_2019/OR0419.VOL successfully.
# Uploading april_2019/PA0419.VOL to ADLS at fhwa_import/2019/april_2019/PA0419.VOL.
# Uploaded april_2019/PA0419.VOL successfully.
# Uploading april_2019/RI0419.VOL to ADLS at fhwa_import/2019/april_2019/RI0419.VOL.
# Uploaded april_2019/RI0419.VOL successfully.
# Uploading april_2019/SC0419.VOL to ADLS at fhwa_import/2019/april_2019/SC0419.VOL.
# Uploaded april_2019/SC0419.VOL successfully.
# Uploading april_2019/SD0419.VOL to ADLS at fhwa_import/2019/april_2019/SD0419.VOL.
# Uploaded april_2019/SD0419.VOL successfully.
# Uploading april_2019/TN0419.VOL to ADLS at fhwa_import/2019/april_2019/TN0419.VOL.
# Uploaded april_2019/TN0419.VOL successfully.
# Uploading april_2019/TX0419.VOL to ADLS at fhwa_import/2019/april_2019/TX0419.VOL.
# Uploaded april_2019/TX0419.VOL successfully.
# Uploading april_2019/UT0419.VOL to ADLS at fhwa_import/2019/april_2019/UT0419.VOL.
# Uploaded april_2019/UT0419.VOL successfully.
# Uploading april_2019/VA0419.VOL to ADLS at fhwa_import/2019/april_2019/VA0419.VOL.
# Uploaded april_2019/VA0419.VOL successfully.
# Uploading april_2019/VT0419.VOL to ADLS at fhwa_import/2019/april_2019/VT0419.VOL.
# Uploaded april_2019/VT0419.VOL successfully.
# Uploading april_2019/WA0419.VOL to ADLS at fhwa_import/2019/april_2019/WA0419.VOL.
# Uploaded april_2019/WA0419.VOL successfully.
# Uploading april_2019/WI0419.VOL to ADLS at fhwa_import/2019/april_2019/WI0419.VOL.
# Uploaded april_2019/WI0419.VOL successfully.
# Uploading april_2019/WV0419.VOL to ADLS at fhwa_import/2019/april_2019/WV0419.VOL.
# Uploaded april_2019/WV0419.VOL successfully.
# Uploading april_2019/WY0419.VOL to ADLS at fhwa_import/2019/april_2019/WY0419.VOL.
# Uploaded april_2019/WY0419.VOL successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/may_2019_ccs_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/may_2019_ccs_data.zip has been successfully stored in memory.
# Uploading may_2019/AK0519.VOL to ADLS at fhwa_import/2019/may_2019/AK0519.VOL.
# Uploaded may_2019/AK0519.VOL successfully.
# Uploading may_2019/AL0519.VOL to ADLS at fhwa_import/2019/may_2019/AL0519.VOL.
# Uploaded may_2019/AL0519.VOL successfully.
# Uploading may_2019/AR0519.VOL to ADLS at fhwa_import/2019/may_2019/AR0519.VOL.
# Uploaded may_2019/AR0519.VOL successfully.
# Uploading may_2019/AZ0519.VOL to ADLS at fhwa_import/2019/may_2019/AZ0519.VOL.
# Uploaded may_2019/AZ0519.VOL successfully.
# Uploading may_2019/CA0519.VOL to ADLS at fhwa_import/2019/may_2019/CA0519.VOL.
# Uploaded may_2019/CA0519.VOL successfully.
# Uploading may_2019/CO0519.VOL to ADLS at fhwa_import/2019/may_2019/CO0519.VOL.
# Uploaded may_2019/CO0519.VOL successfully.
# Uploading may_2019/CT0519.VOL to ADLS at fhwa_import/2019/may_2019/CT0519.VOL.
# Uploaded may_2019/CT0519.VOL successfully.
# Uploading may_2019/DC0519.VOL to ADLS at fhwa_import/2019/may_2019/DC0519.VOL.
# Uploaded may_2019/DC0519.VOL successfully.
# Uploading may_2019/DE0519.VOL to ADLS at fhwa_import/2019/may_2019/DE0519.VOL.
# Uploaded may_2019/DE0519.VOL successfully.
# Uploading may_2019/FL0519.VOL to ADLS at fhwa_import/2019/may_2019/FL0519.VOL.
# Uploaded may_2019/FL0519.VOL successfully.
# Uploading may_2019/GA0519.VOL to ADLS at fhwa_import/2019/may_2019/GA0519.VOL.
# Uploaded may_2019/GA0519.VOL successfully.
# Uploading may_2019/HI0519.VOL to ADLS at fhwa_import/2019/may_2019/HI0519.VOL.
# Uploaded may_2019/HI0519.VOL successfully.
# Uploading may_2019/IA0519.VOL to ADLS at fhwa_import/2019/may_2019/IA0519.VOL.
# Uploaded may_2019/IA0519.VOL successfully.
# Uploading may_2019/ID0519.VOL to ADLS at fhwa_import/2019/may_2019/ID0519.VOL.
# Uploaded may_2019/ID0519.VOL successfully.
# Uploading may_2019/IL0519.VOL to ADLS at fhwa_import/2019/may_2019/IL0519.VOL.
# Uploaded may_2019/IL0519.VOL successfully.
# Uploading may_2019/IN0519.VOL to ADLS at fhwa_import/2019/may_2019/IN0519.VOL.
# Uploaded may_2019/IN0519.VOL successfully.
# Uploading may_2019/KS0519.VOL to ADLS at fhwa_import/2019/may_2019/KS0519.VOL.
# Uploaded may_2019/KS0519.VOL successfully.
# Uploading may_2019/KY0519.VOL to ADLS at fhwa_import/2019/may_2019/KY0519.VOL.
# Uploaded may_2019/KY0519.VOL successfully.
# Uploading may_2019/MA0519.VOL to ADLS at fhwa_import/2019/may_2019/MA0519.VOL.
# Uploaded may_2019/MA0519.VOL successfully.
# Uploading may_2019/MD0519.VOL to ADLS at fhwa_import/2019/may_2019/MD0519.VOL.
# Uploaded may_2019/MD0519.VOL successfully.
# Uploading may_2019/ME0519.VOL to ADLS at fhwa_import/2019/may_2019/ME0519.VOL.
# Uploaded may_2019/ME0519.VOL successfully.
# Uploading may_2019/MI0519.VOL to ADLS at fhwa_import/2019/may_2019/MI0519.VOL.
# Uploaded may_2019/MI0519.VOL successfully.
# Uploading may_2019/MN0519.VOL to ADLS at fhwa_import/2019/may_2019/MN0519.VOL.
# Uploaded may_2019/MN0519.VOL successfully.
# Uploading may_2019/MO0519.VOL to ADLS at fhwa_import/2019/may_2019/MO0519.VOL.
# Uploaded may_2019/MO0519.VOL successfully.
# Uploading may_2019/MS0519.VOL to ADLS at fhwa_import/2019/may_2019/MS0519.VOL.
# Uploaded may_2019/MS0519.VOL successfully.
# Uploading may_2019/MT0519.VOL to ADLS at fhwa_import/2019/may_2019/MT0519.VOL.
# Uploaded may_2019/MT0519.VOL successfully.
# Uploading may_2019/NC0519.VOL to ADLS at fhwa_import/2019/may_2019/NC0519.VOL.
# Uploaded may_2019/NC0519.VOL successfully.
# Uploading may_2019/ND0519.VOL to ADLS at fhwa_import/2019/may_2019/ND0519.VOL.
# Uploaded may_2019/ND0519.VOL successfully.
# Uploading may_2019/NE0519.VOL to ADLS at fhwa_import/2019/may_2019/NE0519.VOL.
# Uploaded may_2019/NE0519.VOL successfully.
# Uploading may_2019/NH0519.VOL to ADLS at fhwa_import/2019/may_2019/NH0519.VOL.
# Uploaded may_2019/NH0519.VOL successfully.
# Uploading may_2019/NJ0519.VOL to ADLS at fhwa_import/2019/may_2019/NJ0519.VOL.
# Uploaded may_2019/NJ0519.VOL successfully.
# Uploading may_2019/NM0519.VOL to ADLS at fhwa_import/2019/may_2019/NM0519.VOL.
# Uploaded may_2019/NM0519.VOL successfully.
# Uploading may_2019/NV0519.VOL to ADLS at fhwa_import/2019/may_2019/NV0519.VOL.
# Uploaded may_2019/NV0519.VOL successfully.
# Uploading may_2019/NY0519.VOL to ADLS at fhwa_import/2019/may_2019/NY0519.VOL.
# Uploaded may_2019/NY0519.VOL successfully.
# Uploading may_2019/OH0519.VOL to ADLS at fhwa_import/2019/may_2019/OH0519.VOL.
# Uploaded may_2019/OH0519.VOL successfully.
# Uploading may_2019/OK0519.VOL to ADLS at fhwa_import/2019/may_2019/OK0519.VOL.
# Uploaded may_2019/OK0519.VOL successfully.
# Uploading may_2019/OR0519.VOL to ADLS at fhwa_import/2019/may_2019/OR0519.VOL.
# Uploaded may_2019/OR0519.VOL successfully.
# Uploading may_2019/PA0519.VOL to ADLS at fhwa_import/2019/may_2019/PA0519.VOL.
# Uploaded may_2019/PA0519.VOL successfully.
# Uploading may_2019/RI0519.VOL to ADLS at fhwa_import/2019/may_2019/RI0519.VOL.
# Uploaded may_2019/RI0519.VOL successfully.
# Uploading may_2019/SC0519.VOL to ADLS at fhwa_import/2019/may_2019/SC0519.VOL.
# Uploaded may_2019/SC0519.VOL successfully.
# Uploading may_2019/SD0519.VOL to ADLS at fhwa_import/2019/may_2019/SD0519.VOL.
# Uploaded may_2019/SD0519.VOL successfully.
# Uploading may_2019/TN0519.VOL to ADLS at fhwa_import/2019/may_2019/TN0519.VOL.
# Uploaded may_2019/TN0519.VOL successfully.
# Uploading may_2019/TX0519.VOL to ADLS at fhwa_import/2019/may_2019/TX0519.VOL.
# Uploaded may_2019/TX0519.VOL successfully.
# Uploading may_2019/UT0519.VOL to ADLS at fhwa_import/2019/may_2019/UT0519.VOL.
# Uploaded may_2019/UT0519.VOL successfully.
# Uploading may_2019/VA0519.VOL to ADLS at fhwa_import/2019/may_2019/VA0519.VOL.
# Uploaded may_2019/VA0519.VOL successfully.
# Uploading may_2019/VT0519.VOL to ADLS at fhwa_import/2019/may_2019/VT0519.VOL.
# Uploaded may_2019/VT0519.VOL successfully.
# Uploading may_2019/WA0519.VOL to ADLS at fhwa_import/2019/may_2019/WA0519.VOL.
# Uploaded may_2019/WA0519.VOL successfully.
# Uploading may_2019/WI0519.VOL to ADLS at fhwa_import/2019/may_2019/WI0519.VOL.
# Uploaded may_2019/WI0519.VOL successfully.
# Uploading may_2019/WV0519.VOL to ADLS at fhwa_import/2019/may_2019/WV0519.VOL.
# Uploaded may_2019/WV0519.VOL successfully.
# Uploading may_2019/WY0519.VOL to ADLS at fhwa_import/2019/may_2019/WY0519.VOL.
# Uploaded may_2019/WY0519.VOL successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/jun_2019_ccs_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/jun_2019_ccs_data.zip has been successfully stored in memory.
# Uploading june_2019/AK0619.VOL to ADLS at fhwa_import/2019/june_2019/AK0619.VOL.
# Uploaded june_2019/AK0619.VOL successfully.
# Uploading june_2019/AL0619.VOL to ADLS at fhwa_import/2019/june_2019/AL0619.VOL.
# Uploaded june_2019/AL0619.VOL successfully.
# Uploading june_2019/AR0619.VOL to ADLS at fhwa_import/2019/june_2019/AR0619.VOL.
# Uploaded june_2019/AR0619.VOL successfully.
# Uploading june_2019/AZ0619.VOL to ADLS at fhwa_import/2019/june_2019/AZ0619.VOL.
# Uploaded june_2019/AZ0619.VOL successfully.
# Uploading june_2019/CA0619.VOL to ADLS at fhwa_import/2019/june_2019/CA0619.VOL.
# Uploaded june_2019/CA0619.VOL successfully.
# Uploading june_2019/CO0619.VOL to ADLS at fhwa_import/2019/june_2019/CO0619.VOL.
# Uploaded june_2019/CO0619.VOL successfully.
# Uploading june_2019/CT0619.VOL to ADLS at fhwa_import/2019/june_2019/CT0619.VOL.
# Uploaded june_2019/CT0619.VOL successfully.
# Uploading june_2019/DC0619.VOL to ADLS at fhwa_import/2019/june_2019/DC0619.VOL.
# Uploaded june_2019/DC0619.VOL successfully.
# Uploading june_2019/DE0619.VOL to ADLS at fhwa_import/2019/june_2019/DE0619.VOL.
# Uploaded june_2019/DE0619.VOL successfully.
# Uploading june_2019/FL0619.VOL to ADLS at fhwa_import/2019/june_2019/FL0619.VOL.
# Uploaded june_2019/FL0619.VOL successfully.
# Uploading june_2019/GA0619.VOL to ADLS at fhwa_import/2019/june_2019/GA0619.VOL.
# Uploaded june_2019/GA0619.VOL successfully.
# Uploading june_2019/HI0619.VOL to ADLS at fhwa_import/2019/june_2019/HI0619.VOL.
# Uploaded june_2019/HI0619.VOL successfully.
# Uploading june_2019/IA0619.VOL to ADLS at fhwa_import/2019/june_2019/IA0619.VOL.
# Uploaded june_2019/IA0619.VOL successfully.
# Uploading june_2019/ID0619.VOL to ADLS at fhwa_import/2019/june_2019/ID0619.VOL.
# Uploaded june_2019/ID0619.VOL successfully.
# Uploading june_2019/IL0619.VOL to ADLS at fhwa_import/2019/june_2019/IL0619.VOL.
# Uploaded june_2019/IL0619.VOL successfully.
# Uploading june_2019/IN0619.VOL to ADLS at fhwa_import/2019/june_2019/IN0619.VOL.
# Uploaded june_2019/IN0619.VOL successfully.
# Uploading june_2019/KS0619.VOL to ADLS at fhwa_import/2019/june_2019/KS0619.VOL.
# Uploaded june_2019/KS0619.VOL successfully.
# Uploading june_2019/KY0619.VOL to ADLS at fhwa_import/2019/june_2019/KY0619.VOL.
# Uploaded june_2019/KY0619.VOL successfully.
# Uploading june_2019/LA0619.VOL to ADLS at fhwa_import/2019/june_2019/LA0619.VOL.
# Uploaded june_2019/LA0619.VOL successfully.
# Uploading june_2019/MA0619.VOL to ADLS at fhwa_import/2019/june_2019/MA0619.VOL.
# Uploaded june_2019/MA0619.VOL successfully.
# Uploading june_2019/MD0619.VOL to ADLS at fhwa_import/2019/june_2019/MD0619.VOL.
# Uploaded june_2019/MD0619.VOL successfully.
# Uploading june_2019/ME0619.VOL to ADLS at fhwa_import/2019/june_2019/ME0619.VOL.
# Uploaded june_2019/ME0619.VOL successfully.
# Uploading june_2019/MI0619.VOL to ADLS at fhwa_import/2019/june_2019/MI0619.VOL.
# Uploaded june_2019/MI0619.VOL successfully.
# Uploading june_2019/MN0619.VOL to ADLS at fhwa_import/2019/june_2019/MN0619.VOL.
# Uploaded june_2019/MN0619.VOL successfully.
# Uploading june_2019/MO0619.VOL to ADLS at fhwa_import/2019/june_2019/MO0619.VOL.
# Uploaded june_2019/MO0619.VOL successfully.
# Uploading june_2019/MS0619.VOL to ADLS at fhwa_import/2019/june_2019/MS0619.VOL.
# Uploaded june_2019/MS0619.VOL successfully.
# Uploading june_2019/MT0619.VOL to ADLS at fhwa_import/2019/june_2019/MT0619.VOL.
# Uploaded june_2019/MT0619.VOL successfully.
# Uploading june_2019/NC0619.VOL to ADLS at fhwa_import/2019/june_2019/NC0619.VOL.
# Uploaded june_2019/NC0619.VOL successfully.
# Uploading june_2019/ND0619.VOL to ADLS at fhwa_import/2019/june_2019/ND0619.VOL.
# Uploaded june_2019/ND0619.VOL successfully.
# Uploading june_2019/NE0619.VOL to ADLS at fhwa_import/2019/june_2019/NE0619.VOL.
# Uploaded june_2019/NE0619.VOL successfully.
# Uploading june_2019/NH0619.VOL to ADLS at fhwa_import/2019/june_2019/NH0619.VOL.
# Uploaded june_2019/NH0619.VOL successfully.
# Uploading june_2019/NJ0619.VOL to ADLS at fhwa_import/2019/june_2019/NJ0619.VOL.
# Uploaded june_2019/NJ0619.VOL successfully.
# Uploading june_2019/NM0619.VOL to ADLS at fhwa_import/2019/june_2019/NM0619.VOL.
# Uploaded june_2019/NM0619.VOL successfully.
# Uploading june_2019/NV0619.VOL to ADLS at fhwa_import/2019/june_2019/NV0619.VOL.
# Uploaded june_2019/NV0619.VOL successfully.
# Uploading june_2019/NY0619.VOL to ADLS at fhwa_import/2019/june_2019/NY0619.VOL.
# Uploaded june_2019/NY0619.VOL successfully.
# Uploading june_2019/OH0619.VOL to ADLS at fhwa_import/2019/june_2019/OH0619.VOL.
# Uploaded june_2019/OH0619.VOL successfully.
# Uploading june_2019/OK0619.VOL to ADLS at fhwa_import/2019/june_2019/OK0619.VOL.
# Uploaded june_2019/OK0619.VOL successfully.
# Uploading june_2019/OR0619.VOL to ADLS at fhwa_import/2019/june_2019/OR0619.VOL.
# Uploaded june_2019/OR0619.VOL successfully.
# Uploading june_2019/PA0619.VOL to ADLS at fhwa_import/2019/june_2019/PA0619.VOL.
# Uploaded june_2019/PA0619.VOL successfully.
# Uploading june_2019/RI0619.VOL to ADLS at fhwa_import/2019/june_2019/RI0619.VOL.
# Uploaded june_2019/RI0619.VOL successfully.
# Uploading june_2019/SC0619.VOL to ADLS at fhwa_import/2019/june_2019/SC0619.VOL.
# Uploaded june_2019/SC0619.VOL successfully.
# Uploading june_2019/SD0619.VOL to ADLS at fhwa_import/2019/june_2019/SD0619.VOL.
# Uploaded june_2019/SD0619.VOL successfully.
# Uploading june_2019/TN0619.VOL to ADLS at fhwa_import/2019/june_2019/TN0619.VOL.
# Uploaded june_2019/TN0619.VOL successfully.
# Uploading june_2019/TX0619.VOL to ADLS at fhwa_import/2019/june_2019/TX0619.VOL.
# Uploaded june_2019/TX0619.VOL successfully.
# Uploading june_2019/UT0619.VOL to ADLS at fhwa_import/2019/june_2019/UT0619.VOL.
# Uploaded june_2019/UT0619.VOL successfully.
# Uploading june_2019/VA0619.VOL to ADLS at fhwa_import/2019/june_2019/VA0619.VOL.
# Uploaded june_2019/VA0619.VOL successfully.
# Uploading june_2019/VT0619.VOL to ADLS at fhwa_import/2019/june_2019/VT0619.VOL.
# Uploaded june_2019/VT0619.VOL successfully.
# Uploading june_2019/WA0619.VOL to ADLS at fhwa_import/2019/june_2019/WA0619.VOL.
# Uploaded june_2019/WA0619.VOL successfully.
# Uploading june_2019/WI0619.VOL to ADLS at fhwa_import/2019/june_2019/WI0619.VOL.
# Uploaded june_2019/WI0619.VOL successfully.
# Uploading june_2019/WV0619.VOL to ADLS at fhwa_import/2019/june_2019/WV0619.VOL.
# Uploaded june_2019/WV0619.VOL successfully.
# Uploading june_2019/WY0619.VOL to ADLS at fhwa_import/2019/june_2019/WY0619.VOL.
# Uploaded june_2019/WY0619.VOL successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/jul_2019_ccs_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/jul_2019_ccs_data.zip has been successfully stored in memory.
# Uploading july_2019/AK0719.VOL to ADLS at fhwa_import/2019/july_2019/AK0719.VOL.
# Uploaded july_2019/AK0719.VOL successfully.
# Uploading july_2019/AL0719.VOL to ADLS at fhwa_import/2019/july_2019/AL0719.VOL.
# Uploaded july_2019/AL0719.VOL successfully.
# Uploading july_2019/AR0719.VOL to ADLS at fhwa_import/2019/july_2019/AR0719.VOL.
# Uploaded july_2019/AR0719.VOL successfully.
# Uploading july_2019/AZ0719.VOL to ADLS at fhwa_import/2019/july_2019/AZ0719.VOL.
# Uploaded july_2019/AZ0719.VOL successfully.
# Uploading july_2019/CA0719.VOL to ADLS at fhwa_import/2019/july_2019/CA0719.VOL.
# Uploaded july_2019/CA0719.VOL successfully.
# Uploading july_2019/CO0719.VOL to ADLS at fhwa_import/2019/july_2019/CO0719.VOL.
# Uploaded july_2019/CO0719.VOL successfully.
# Uploading july_2019/CT0719.VOL to ADLS at fhwa_import/2019/july_2019/CT0719.VOL.
# Uploaded july_2019/CT0719.VOL successfully.
# Uploading july_2019/DC0719.VOL to ADLS at fhwa_import/2019/july_2019/DC0719.VOL.
# Uploaded july_2019/DC0719.VOL successfully.
# Uploading july_2019/DE0719.VOL to ADLS at fhwa_import/2019/july_2019/DE0719.VOL.
# Uploaded july_2019/DE0719.VOL successfully.
# Uploading july_2019/FL0719.VOL to ADLS at fhwa_import/2019/july_2019/FL0719.VOL.
# Uploaded july_2019/FL0719.VOL successfully.
# Uploading july_2019/GA0719.VOL to ADLS at fhwa_import/2019/july_2019/GA0719.VOL.
# Uploaded july_2019/GA0719.VOL successfully.
# Uploading july_2019/HI0719.VOL to ADLS at fhwa_import/2019/july_2019/HI0719.VOL.
# Uploaded july_2019/HI0719.VOL successfully.
# Uploading july_2019/IA0719.VOL to ADLS at fhwa_import/2019/july_2019/IA0719.VOL.
# Uploaded july_2019/IA0719.VOL successfully.
# Uploading july_2019/ID0719.VOL to ADLS at fhwa_import/2019/july_2019/ID0719.VOL.
# Uploaded july_2019/ID0719.VOL successfully.
# Uploading july_2019/IL0719.VOL to ADLS at fhwa_import/2019/july_2019/IL0719.VOL.
# Uploaded july_2019/IL0719.VOL successfully.
# Uploading july_2019/IN0719.VOL to ADLS at fhwa_import/2019/july_2019/IN0719.VOL.
# Uploaded july_2019/IN0719.VOL successfully.
# Uploading july_2019/KS0719.VOL to ADLS at fhwa_import/2019/july_2019/KS0719.VOL.
# Uploaded july_2019/KS0719.VOL successfully.
# Uploading july_2019/KY0719.VOL to ADLS at fhwa_import/2019/july_2019/KY0719.VOL.
# Uploaded july_2019/KY0719.VOL successfully.
# Uploading july_2019/LA0719.VOL to ADLS at fhwa_import/2019/july_2019/LA0719.VOL.
# Uploaded july_2019/LA0719.VOL successfully.
# Uploading july_2019/MA0719.VOL to ADLS at fhwa_import/2019/july_2019/MA0719.VOL.
# Uploaded july_2019/MA0719.VOL successfully.
# Uploading july_2019/MD0719.VOL to ADLS at fhwa_import/2019/july_2019/MD0719.VOL.
# Uploaded july_2019/MD0719.VOL successfully.
# Uploading july_2019/ME0719.VOL to ADLS at fhwa_import/2019/july_2019/ME0719.VOL.
# Uploaded july_2019/ME0719.VOL successfully.
# Uploading july_2019/MI0719.VOL to ADLS at fhwa_import/2019/july_2019/MI0719.VOL.
# Uploaded july_2019/MI0719.VOL successfully.
# Uploading july_2019/MN0719.VOL to ADLS at fhwa_import/2019/july_2019/MN0719.VOL.
# Uploaded july_2019/MN0719.VOL successfully.
# Uploading july_2019/MO0719.VOL to ADLS at fhwa_import/2019/july_2019/MO0719.VOL.
# Uploaded july_2019/MO0719.VOL successfully.
# Uploading july_2019/MS0719.VOL to ADLS at fhwa_import/2019/july_2019/MS0719.VOL.
# Uploaded july_2019/MS0719.VOL successfully.
# Uploading july_2019/MT0719.VOL to ADLS at fhwa_import/2019/july_2019/MT0719.VOL.
# Uploaded july_2019/MT0719.VOL successfully.
# Uploading july_2019/NC0719.VOL to ADLS at fhwa_import/2019/july_2019/NC0719.VOL.
# Uploaded july_2019/NC0719.VOL successfully.
# Uploading july_2019/ND0719.VOL to ADLS at fhwa_import/2019/july_2019/ND0719.VOL.
# Uploaded july_2019/ND0719.VOL successfully.
# Uploading july_2019/NE0719.VOL to ADLS at fhwa_import/2019/july_2019/NE0719.VOL.
# Uploaded july_2019/NE0719.VOL successfully.
# Uploading july_2019/NH0719.VOL to ADLS at fhwa_import/2019/july_2019/NH0719.VOL.
# Uploaded july_2019/NH0719.VOL successfully.
# Uploading july_2019/NJ0719.VOL to ADLS at fhwa_import/2019/july_2019/NJ0719.VOL.
# Uploaded july_2019/NJ0719.VOL successfully.
# Uploading july_2019/NM0719.VOL to ADLS at fhwa_import/2019/july_2019/NM0719.VOL.
# Uploaded july_2019/NM0719.VOL successfully.
# Uploading july_2019/NV0719.VOL to ADLS at fhwa_import/2019/july_2019/NV0719.VOL.
# Uploaded july_2019/NV0719.VOL successfully.
# Uploading july_2019/NY0719.VOL to ADLS at fhwa_import/2019/july_2019/NY0719.VOL.
# Uploaded july_2019/NY0719.VOL successfully.
# Uploading july_2019/OH0719.VOL to ADLS at fhwa_import/2019/july_2019/OH0719.VOL.
# Uploaded july_2019/OH0719.VOL successfully.
# Uploading july_2019/OK0719.VOL to ADLS at fhwa_import/2019/july_2019/OK0719.VOL.
# Uploaded july_2019/OK0719.VOL successfully.
# Uploading july_2019/OR0719.VOL to ADLS at fhwa_import/2019/july_2019/OR0719.VOL.
# Uploaded july_2019/OR0719.VOL successfully.
# Uploading july_2019/PA0719.VOL to ADLS at fhwa_import/2019/july_2019/PA0719.VOL.
# Uploaded july_2019/PA0719.VOL successfully.
# Uploading july_2019/RI0719.VOL to ADLS at fhwa_import/2019/july_2019/RI0719.VOL.
# Uploaded july_2019/RI0719.VOL successfully.
# Uploading july_2019/SC0719.VOL to ADLS at fhwa_import/2019/july_2019/SC0719.VOL.
# Uploaded july_2019/SC0719.VOL successfully.
# Uploading july_2019/SD0719.VOL to ADLS at fhwa_import/2019/july_2019/SD0719.VOL.
# Uploaded july_2019/SD0719.VOL successfully.
# Uploading july_2019/TN0719.VOL to ADLS at fhwa_import/2019/july_2019/TN0719.VOL.
# Uploaded july_2019/TN0719.VOL successfully.
# Uploading july_2019/TX0719.VOL to ADLS at fhwa_import/2019/july_2019/TX0719.VOL.
# Uploaded july_2019/TX0719.VOL successfully.
# Uploading july_2019/UT0719.VOL to ADLS at fhwa_import/2019/july_2019/UT0719.VOL.
# Uploaded july_2019/UT0719.VOL successfully.
# Uploading july_2019/VA0719.VOL to ADLS at fhwa_import/2019/july_2019/VA0719.VOL.
# Uploaded july_2019/VA0719.VOL successfully.
# Uploading july_2019/VT0719.VOL to ADLS at fhwa_import/2019/july_2019/VT0719.VOL.
# Uploaded july_2019/VT0719.VOL successfully.
# Uploading july_2019/WA0719.VOL to ADLS at fhwa_import/2019/july_2019/WA0719.VOL.
# Uploaded july_2019/WA0719.VOL successfully.
# Uploading july_2019/WI0719.VOL to ADLS at fhwa_import/2019/july_2019/WI0719.VOL.
# Uploaded july_2019/WI0719.VOL successfully.
# Uploading july_2019/WV0719.VOL to ADLS at fhwa_import/2019/july_2019/WV0719.VOL.
# Uploaded july_2019/WV0719.VOL successfully.
# Uploading july_2019/WY0719.VOL to ADLS at fhwa_import/2019/july_2019/WY0719.VOL.
# Uploaded july_2019/WY0719.VOL successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2019/aug_2019_ccs_data.zip.
# ...
# Uploaded NY_OCT_2023 (TMAS).VOL successfully.
# Uploading OH_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/OH_OCT_2023 (TMAS).VOL.
# Uploaded OH_OCT_2023 (TMAS).VOL successfully.
# Uploading OK_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/OK_OCT_2023 (TMAS).VOL.
# Uploaded OK_OCT_2023 (TMAS).VOL successfully.
# Uploading OR_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/OR_OCT_2023 (TMAS).VOL.
# Uploaded OR_OCT_2023 (TMAS).VOL successfully.
# Uploading PA_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/PA_OCT_2023 (TMAS).VOL.
# Uploaded PA_OCT_2023 (TMAS).VOL successfully.
# Uploading RI_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/RI_OCT_2023 (TMAS).VOL.
# Uploaded RI_OCT_2023 (TMAS).VOL successfully.
# Uploading SC_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/SC_OCT_2023 (TMAS).VOL.
# Uploaded SC_OCT_2023 (TMAS).VOL successfully.
# Uploading SD_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/SD_OCT_2023 (TMAS).VOL.
# Uploaded SD_OCT_2023 (TMAS).VOL successfully.
# Uploading TN_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/TN_OCT_2023 (TMAS).VOL.
# Uploaded TN_OCT_2023 (TMAS).VOL successfully.
# Uploading TX_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/TX_OCT_2023 (TMAS).VOL.
# Uploaded TX_OCT_2023 (TMAS).VOL successfully.
# Uploading UT_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/UT_OCT_2023 (TMAS).VOL.
# Uploaded UT_OCT_2023 (TMAS).VOL successfully.
# Uploading VA_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/VA_OCT_2023 (TMAS).VOL.
# Uploaded VA_OCT_2023 (TMAS).VOL successfully.
# Uploading VT_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/VT_OCT_2023 (TMAS).VOL.
# Uploaded VT_OCT_2023 (TMAS).VOL successfully.
# Uploading WA_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WA_OCT_2023 (TMAS).VOL.
# Uploaded WA_OCT_2023 (TMAS).VOL successfully.
# Uploading WI_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WI_OCT_2023 (TMAS).VOL.
# Uploaded WI_OCT_2023 (TMAS).VOL successfully.
# Uploading WV_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WV_OCT_2023 (TMAS).VOL.
# Uploaded WV_OCT_2023 (TMAS).VOL successfully.
# Uploading WY_OCT_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WY_OCT_2023 (TMAS).VOL.
# Uploaded WY_OCT_2023 (TMAS).VOL successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2023/nov_2023_ccs_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2023/nov_2023_ccs_data.zip has been successfully stored in memory.
# Uploading AK_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/AK_NOV_2023 (TMAS).VOL.
# Uploaded AK_NOV_2023 (TMAS).VOL successfully.
# Uploading AL_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/AL_NOV_2023 (TMAS).VOL.
# Uploaded AL_NOV_2023 (TMAS).VOL successfully.
# Uploading AR_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/AR_NOV_2023 (TMAS).VOL.
# Uploaded AR_NOV_2023 (TMAS).VOL successfully.
# Uploading AZ_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/AZ_NOV_2023 (TMAS).VOL.
# Uploaded AZ_NOV_2023 (TMAS).VOL successfully.
# Uploading CA_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/CA_NOV_2023 (TMAS).VOL.
# Uploaded CA_NOV_2023 (TMAS).VOL successfully.
# Uploading CO_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/CO_NOV_2023 (TMAS).VOL.
# Uploaded CO_NOV_2023 (TMAS).VOL successfully.
# Uploading CT_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/CT_NOV_2023 (TMAS).VOL.
# Uploaded CT_NOV_2023 (TMAS).VOL successfully.
# Uploading DC_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/DC_NOV_2023 (TMAS).VOL.
# Uploaded DC_NOV_2023 (TMAS).VOL successfully.
# Uploading DE_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/DE_NOV_2023 (TMAS).VOL.
# Uploaded DE_NOV_2023 (TMAS).VOL successfully.
# Uploading FL_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/FL_NOV_2023 (TMAS).VOL.
# Uploaded FL_NOV_2023 (TMAS).VOL successfully.
# Uploading GA_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/GA_NOV_2023 (TMAS).VOL.
# Uploaded GA_NOV_2023 (TMAS).VOL successfully.
# Uploading HI_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/HI_NOV_2023 (TMAS).VOL.
# Uploaded HI_NOV_2023 (TMAS).VOL successfully.
# Uploading IA_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/IA_NOV_2023 (TMAS).VOL.
# Uploaded IA_NOV_2023 (TMAS).VOL successfully.
# Uploading ID_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/ID_NOV_2023 (TMAS).VOL.
# Uploaded ID_NOV_2023 (TMAS).VOL successfully.
# Uploading IL_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/IL_NOV_2023 (TMAS).VOL.
# Uploaded IL_NOV_2023 (TMAS).VOL successfully.
# Uploading IN_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/IN_NOV_2023 (TMAS).VOL.
# Uploaded IN_NOV_2023 (TMAS).VOL successfully.
# Uploading KS_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/KS_NOV_2023 (TMAS).VOL.
# Uploaded KS_NOV_2023 (TMAS).VOL successfully.
# Uploading KY_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/KY_NOV_2023 (TMAS).VOL.
# Uploaded KY_NOV_2023 (TMAS).VOL successfully.
# Uploading LA_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/LA_NOV_2023 (TMAS).VOL.
# Uploaded LA_NOV_2023 (TMAS).VOL successfully.
# Uploading MA_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MA_NOV_2023 (TMAS).VOL.
# Uploaded MA_NOV_2023 (TMAS).VOL successfully.
# Uploading MD_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MD_NOV_2023 (TMAS).VOL.
# Uploaded MD_NOV_2023 (TMAS).VOL successfully.
# Uploading ME_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/ME_NOV_2023 (TMAS).VOL.
# Uploaded ME_NOV_2023 (TMAS).VOL successfully.
# Uploading MI_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MI_NOV_2023 (TMAS).VOL.
# Uploaded MI_NOV_2023 (TMAS).VOL successfully.
# Uploading MN_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MN_NOV_2023 (TMAS).VOL.
# Uploaded MN_NOV_2023 (TMAS).VOL successfully.
# Uploading MO_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MO_NOV_2023 (TMAS).VOL.
# Uploaded MO_NOV_2023 (TMAS).VOL successfully.
# Uploading MS_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MS_NOV_2023 (TMAS).VOL.
# Uploaded MS_NOV_2023 (TMAS).VOL successfully.
# Uploading MT_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MT_NOV_2023 (TMAS).VOL.
# Uploaded MT_NOV_2023 (TMAS).VOL successfully.
# Uploading NC_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NC_NOV_2023 (TMAS).VOL.
# Uploaded NC_NOV_2023 (TMAS).VOL successfully.
# Uploading ND_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/ND_NOV_2023 (TMAS).VOL.
# Uploaded ND_NOV_2023 (TMAS).VOL successfully.
# Uploading NE_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NE_NOV_2023 (TMAS).VOL.
# Uploaded NE_NOV_2023 (TMAS).VOL successfully.
# Uploading NH_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NH_NOV_2023 (TMAS).VOL.
# Uploaded NH_NOV_2023 (TMAS).VOL successfully.
# Uploading NJ_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NJ_NOV_2023 (TMAS).VOL.
# Uploaded NJ_NOV_2023 (TMAS).VOL successfully.
# Uploading NM_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NM_NOV_2023 (TMAS).VOL.
# Uploaded NM_NOV_2023 (TMAS).VOL successfully.
# Uploading NV_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NV_NOV_2023 (TMAS).VOL.
# Uploaded NV_NOV_2023 (TMAS).VOL successfully.
# Uploading NY_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NY_NOV_2023 (TMAS).VOL.
# Uploaded NY_NOV_2023 (TMAS).VOL successfully.
# Uploading OH_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/OH_NOV_2023 (TMAS).VOL.
# Uploaded OH_NOV_2023 (TMAS).VOL successfully.
# Uploading OK_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/OK_NOV_2023 (TMAS).VOL.
# Uploaded OK_NOV_2023 (TMAS).VOL successfully.
# Uploading OR_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/OR_NOV_2023 (TMAS).VOL.
# Uploaded OR_NOV_2023 (TMAS).VOL successfully.
# Uploading PA_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/PA_NOV_2023 (TMAS).VOL.
# Uploaded PA_NOV_2023 (TMAS).VOL successfully.
# Uploading RI_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/RI_NOV_2023 (TMAS).VOL.
# Uploaded RI_NOV_2023 (TMAS).VOL successfully.
# Uploading SC_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/SC_NOV_2023 (TMAS).VOL.
# Uploaded SC_NOV_2023 (TMAS).VOL successfully.
# Uploading SD_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/SD_NOV_2023 (TMAS).VOL.
# Uploaded SD_NOV_2023 (TMAS).VOL successfully.
# Uploading TN_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/TN_NOV_2023 (TMAS).VOL.
# Uploaded TN_NOV_2023 (TMAS).VOL successfully.
# Uploading TX_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/TX_NOV_2023 (TMAS).VOL.
# Uploaded TX_NOV_2023 (TMAS).VOL successfully.
# Uploading UT_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/UT_NOV_2023 (TMAS).VOL.
# Uploaded UT_NOV_2023 (TMAS).VOL successfully.
# Uploading VA_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/VA_NOV_2023 (TMAS).VOL.
# Uploaded VA_NOV_2023 (TMAS).VOL successfully.
# Uploading VT_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/VT_NOV_2023 (TMAS).VOL.
# Uploaded VT_NOV_2023 (TMAS).VOL successfully.
# Uploading WA_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WA_NOV_2023 (TMAS).VOL.
# Uploaded WA_NOV_2023 (TMAS).VOL successfully.
# Uploading WI_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WI_NOV_2023 (TMAS).VOL.
# Uploaded WI_NOV_2023 (TMAS).VOL successfully.
# Uploading WV_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WV_NOV_2023 (TMAS).VOL.
# Uploaded WV_NOV_2023 (TMAS).VOL successfully.
# Uploading WY_NOV_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WY_NOV_2023 (TMAS).VOL.
# Uploaded WY_NOV_2023 (TMAS).VOL successfully.
# Retrieving zip file from https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2023/dec_2023_ccs_data.zip.
# https://www.fhwa.dot.gov/policyinformation/tables/tmasdata/2023/dec_2023_ccs_data.zip has been successfully stored in memory.
# Uploading AK_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/AK_DEC_2023 (TMAS).VOL.
# Uploaded AK_DEC_2023 (TMAS).VOL successfully.
# Uploading AL_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/AL_DEC_2023 (TMAS).VOL.
# Uploaded AL_DEC_2023 (TMAS).VOL successfully.
# Uploading AR_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/AR_DEC_2023 (TMAS).VOL.
# Uploaded AR_DEC_2023 (TMAS).VOL successfully.
# Uploading AZ_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/AZ_DEC_2023 (TMAS).VOL.
# Uploaded AZ_DEC_2023 (TMAS).VOL successfully.
# Uploading CA_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/CA_DEC_2023 (TMAS).VOL.
# Uploaded CA_DEC_2023 (TMAS).VOL successfully.
# Uploading CO_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/CO_DEC_2023 (TMAS).VOL.
# Uploaded CO_DEC_2023 (TMAS).VOL successfully.
# Uploading CT_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/CT_DEC_2023 (TMAS).VOL.
# Uploaded CT_DEC_2023 (TMAS).VOL successfully.
# Uploading DC_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/DC_DEC_2023 (TMAS).VOL.
# Uploaded DC_DEC_2023 (TMAS).VOL successfully.
# Uploading DE_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/DE_DEC_2023 (TMAS).VOL.
# Uploaded DE_DEC_2023 (TMAS).VOL successfully.
# Uploading FL_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/FL_DEC_2023 (TMAS).VOL.
# Uploaded FL_DEC_2023 (TMAS).VOL successfully.
# Uploading GA_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/GA_DEC_2023 (TMAS).VOL.
# Uploaded GA_DEC_2023 (TMAS).VOL successfully.
# Uploading HI_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/HI_DEC_2023 (TMAS).VOL.
# Uploaded HI_DEC_2023 (TMAS).VOL successfully.
# Uploading IA_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/IA_DEC_2023 (TMAS).VOL.
# Uploaded IA_DEC_2023 (TMAS).VOL successfully.
# Uploading ID_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/ID_DEC_2023 (TMAS).VOL.
# Uploaded ID_DEC_2023 (TMAS).VOL successfully.
# Uploading IL_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/IL_DEC_2023 (TMAS).VOL.
# Uploaded IL_DEC_2023 (TMAS).VOL successfully.
# Uploading IN_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/IN_DEC_2023 (TMAS).VOL.
# Uploaded IN_DEC_2023 (TMAS).VOL successfully.
# Uploading KS_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/KS_DEC_2023 (TMAS).VOL.
# Uploaded KS_DEC_2023 (TMAS).VOL successfully.
# Uploading KY_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/KY_DEC_2023 (TMAS).VOL.
# Uploaded KY_DEC_2023 (TMAS).VOL successfully.
# Uploading LA_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/LA_DEC_2023 (TMAS).VOL.
# Uploaded LA_DEC_2023 (TMAS).VOL successfully.
# Uploading MA_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MA_DEC_2023 (TMAS).VOL.
# Uploaded MA_DEC_2023 (TMAS).VOL successfully.
# Uploading MD_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MD_DEC_2023 (TMAS).VOL.
# Uploaded MD_DEC_2023 (TMAS).VOL successfully.
# Uploading ME_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/ME_DEC_2023 (TMAS).VOL.
# Uploaded ME_DEC_2023 (TMAS).VOL successfully.
# Uploading MI_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MI_DEC_2023 (TMAS).VOL.
# Uploaded MI_DEC_2023 (TMAS).VOL successfully.
# Uploading MN_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MN_DEC_2023 (TMAS).VOL.
# Uploaded MN_DEC_2023 (TMAS).VOL successfully.
# Uploading MO_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MO_DEC_2023 (TMAS).VOL.
# Uploaded MO_DEC_2023 (TMAS).VOL successfully.
# Uploading MS_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MS_DEC_2023 (TMAS).VOL.
# Uploaded MS_DEC_2023 (TMAS).VOL successfully.
# Uploading MT_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/MT_DEC_2023 (TMAS).VOL.
# Uploaded MT_DEC_2023 (TMAS).VOL successfully.
# Uploading NC_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NC_DEC_2023 (TMAS).VOL.
# Uploaded NC_DEC_2023 (TMAS).VOL successfully.
# Uploading ND_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/ND_DEC_2023 (TMAS).VOL.
# Uploaded ND_DEC_2023 (TMAS).VOL successfully.
# Uploading NE_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NE_DEC_2023 (TMAS).VOL.
# Uploaded NE_DEC_2023 (TMAS).VOL successfully.
# Uploading NH_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NH_DEC_2023 (TMAS).VOL.
# Uploaded NH_DEC_2023 (TMAS).VOL successfully.
# Uploading NJ_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NJ_DEC_2023 (TMAS).VOL.
# Uploaded NJ_DEC_2023 (TMAS).VOL successfully.
# Uploading NM_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NM_DEC_2023 (TMAS).VOL.
# Uploaded NM_DEC_2023 (TMAS).VOL successfully.
# Uploading NV_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NV_DEC_2023 (TMAS).VOL.
# Uploaded NV_DEC_2023 (TMAS).VOL successfully.
# Uploading NY_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/NY_DEC_2023 (TMAS).VOL.
# Uploaded NY_DEC_2023 (TMAS).VOL successfully.
# Uploading OH_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/OH_DEC_2023 (TMAS).VOL.
# Uploaded OH_DEC_2023 (TMAS).VOL successfully.
# Uploading OK_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/OK_DEC_2023 (TMAS).VOL.
# Uploaded OK_DEC_2023 (TMAS).VOL successfully.
# Uploading OR_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/OR_DEC_2023 (TMAS).VOL.
# Uploaded OR_DEC_2023 (TMAS).VOL successfully.
# Uploading PA_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/PA_DEC_2023 (TMAS).VOL.
# Uploaded PA_DEC_2023 (TMAS).VOL successfully.
# Uploading RI_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/RI_DEC_2023 (TMAS).VOL.
# Uploaded RI_DEC_2023 (TMAS).VOL successfully.
# Uploading SC_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/SC_DEC_2023 (TMAS).VOL.
# Uploaded SC_DEC_2023 (TMAS).VOL successfully.
# Uploading SD_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/SD_DEC_2023 (TMAS).VOL.
# Uploaded SD_DEC_2023 (TMAS).VOL successfully.
# Uploading TN_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/TN_DEC_2023 (TMAS).VOL.
# Uploaded TN_DEC_2023 (TMAS).VOL successfully.
# Uploading TX_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/TX_DEC_2023 (TMAS).VOL.
# Uploaded TX_DEC_2023 (TMAS).VOL successfully.
# Uploading UT_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/UT_DEC_2023 (TMAS).VOL.
# Uploaded UT_DEC_2023 (TMAS).VOL successfully.
# Uploading VA_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/VA_DEC_2023 (TMAS).VOL.
# Uploaded VA_DEC_2023 (TMAS).VOL successfully.
# Uploading VT_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/VT_DEC_2023 (TMAS).VOL.
# Uploaded VT_DEC_2023 (TMAS).VOL successfully.
# Uploading WA_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WA_DEC_2023 (TMAS).VOL.
# Uploaded WA_DEC_2023 (TMAS).VOL successfully.
# Uploading WI_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WI_DEC_2023 (TMAS).VOL.
# Uploaded WI_DEC_2023 (TMAS).VOL successfully.
# Uploading WV_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WV_DEC_2023 (TMAS).VOL.
# Uploaded WV_DEC_2023 (TMAS).VOL successfully.
# Uploading WY_DEC_2023 (TMAS).VOL to ADLS at fhwa_import/2023/WY_DEC_2023 (TMAS).VOL.
# Uploaded WY_DEC_2023 (TMAS).VOL successfully.
